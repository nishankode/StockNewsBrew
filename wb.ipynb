# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime, timedelta
import re
from google import genai
import os

# %%
def get_article(article_url):
    """
    Scrapes detailed information from a Moneycontrol article page.

    Args:
        article_url (str): URL of the article.

    Returns:
        dict: Dictionary containing article metadata and content.
    """
    try:
        response = requests.get(article_url, headers={'User-Agent': 'Mozilla/5.0'}, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.content.decode("utf-8", "ignore"), "html.parser")
    except Exception as e:
        raise RuntimeError(f"Failed to fetch or parse article: {e}")

    article = {}

    # Title
    title_tag = soup.find(attrs={"class": "article_title"})
    article["title"] = title_tag.string.strip() if title_tag and title_tag.string else None

    # Summary
    summary_tag = soup.find(attrs={"class": "article_desc"})
    article["summary"] = summary_tag.string.strip() if summary_tag and summary_tag.string else None

    # Timestamp
    time_tag = soup.find(attrs={"class": "article_schedule"})
    time_date_string = ""
    if time_tag:
        for element in time_tag.contents:
            if hasattr(element, 'string') and element.string and element.string.strip():
                time_date_string += element.string.strip()
    article["timestamp"] = time_date_string or None

    # Author
    author_tag = soup.select_one(".content_block span")
    article["author"] = author_tag.string.strip() if author_tag and author_tag.string else None

    # Image URL
    img_tag = soup.select_one(".article_image img")
    article["img_url"] = img_tag["data-src"] if img_tag and img_tag.has_attr("data-src") else None

    # Article content
    content_tags = soup.select(".content_wrapper > p")
    content = [c.get_text(strip=True) for c in content_tags if c.get_text(strip=True)]
    article["content"] = " ".join(content) if content else None

    # Tags
    tag_links = soup.select(".tags_first_line > a")
    article["tags"] = [tag.get_text(strip=True).lstrip("#") for tag in tag_links if tag.get_text(strip=True)]

    return article

# %%
def get_news_links(pages=1):
    """
    Scrapes news article links from Moneycontrol's 'stocks' section.

    Args:
        pages (int): Number of paginated pages to scrape.

    Returns:
        list: Filtered list of unique article URLs from the 'markets' subsection.
    """
    base_url = "https://www.moneycontrol.com/news/business/stocks/page-{}/"
    target_prefix = "https://www.moneycontrol.com/news/"
    market_prefix = "https://www.moneycontrol.com/news/business/markets/"

    headers = {'User-Agent': 'Mozilla/5.0'}
    links = []

    for i in range(pages):
        url = base_url.format(i)
        try:
            response = requests.get(url, headers=headers, timeout=10)
            response.raise_for_status()
        except requests.RequestException as e:
            print(f"❌ Failed to fetch page {i}: {e}")
            continue

        soup = BeautifulSoup(response.text, 'html.parser')
        containers = soup.find_all(class_='clearfix')

        for container in containers:
            for a in container.find_all('a', href=True):
                full_url = urljoin(url, a['href'])
                if full_url.startswith(target_prefix):
                    links.append(full_url)

    # Remove duplicates and filter only 'markets' section links
    updated_links = [
        link for link in set(links)
        if link.startswith(market_prefix) and link != market_prefix
    ]

    return updated_links

# %%
updated_links = get_news_links(10)

# %%
def scrape_articles_multithreaded(links, get_article_func, max_workers=10):
    """
    Fetch articles concurrently using multithreading.

    Args:
        links (list): List of URLs to scrape.
        get_article_func (callable): Function to call for each URL. Should accept a single URL argument.
        max_workers (int): Number of threads to use.

    Returns:
        list: List of successfully fetched article results.
    """
    all_articles = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_url = {executor.submit(get_article_func, link): link for link in links}
        
        for future in as_completed(future_to_url):
            link = future_to_url[future]
            try:
                article = future.result()
                all_articles.append(article)
                print(f"✅ Completed: {link}")
            except Exception as e:
                print(f"❌ Failed: {link} | Reason: {e}")
    
    return all_articles

# %%
all_articles_raw = scrape_articles_multithreaded(updated_links, get_article)
# Out:
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/bharat-forge-emerges-as-l1-bidder-in-army-s-tender-with-cqb-carbine-designed-by-drdo-13163413.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/sebi-grants-investors-more-flexibility-to-co-invest-with-alternative-investment-funds-aifs-13138707.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/m-m-shares-in-focus-as-it-incorporates-arm-mahindra-advanced-technologies-12988023.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/bharat-electronics-shares-in-focus-on-rs-2-210-crore-order-win-from-defence-ministry-12987866.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/mutual-fund-assets-double-to-31-of-bank-deposits-in-10-years-uday-kotak-says-savers-turning-investors-13152025.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/wall-street-trades-lower-as-trump-threatens-china-with-steeper-tariffs-markets-near-bear-territory-12987885.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/markets-end-higher-for-second-week-nifty-eyes-25-650-as-bulls-regain-control-13157030.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/gainers-losers-top-stocks-that-moved-the-most-on-june-20-13152298.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/siemens-energy-set-to-debut-bourses-today-what-should-you-expect-13143657.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/first-tick-here-are-the-top-global-cues-for-today-s-trade-117-13137959.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/bajaj-auto-hero-motocorp-shares-fall-over-2-as-china-s-rare-earth-exports-drop-53-in-may-13150887.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/top-gainers-and-losers-today-stocks-that-moved-the-most-on-april-7-12987627.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/sensex-nifty-make-a-muted-start-amid-middle-east-conflict-hawkish-fed-it-metal-stocks-fall-13143752.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/stocks-to-watch-today-zen-technologies-nlc-india-bajel-projects-bharat-electronics-granules-india-waaree-renewable-in-focus-on-23-june-13161560.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/taking-stock-nifty-below-25-000-despite-recovery-from-lows-as-crude-oil-simmers-after-strike-on-iran-13163696.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/swiggy-hyundai-waaree-energies-other-stocks-jump-up-to-8-after-inclusion-into-london-s-ftse-index-13151620.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/wockhardt-shares-jump-8-amid-high-trading-volumes-pharma-stock-extends-gains-to-45-in-one-month-13137570.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/it-shares-snap-three-day-gaining-streak-ahead-of-us-fed-meet-coforge-tcs-others-fall-up-to-1-5-13137066.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/mid-smallcap-indices-gain-up-to-2-in-early-trading-on-tariff-talk-hopes-12988085.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/sensex-nifty-snap-3-day-losing-streak-as-bank-auto-stocks-gain-india-vix-eases-4-13150398.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/trent-shares-fall-1-despite-macquarie-s-outperform-call-sees-25-upside-potential-13144013.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/hero-moto-m-m-others-tumble-up-to-2-dragging-nifty-auto-after-a-three-day-rise-13164236.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/inventurus-knowledge-solutions-falls-4-as-shares-worth-rs-499-crore-change-hands-13143569.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/midcap-smallcap-indices-rise-over-1-from-day-s-low-despite-weakness-in-benchmarks-zen-tech-polycab-among-top-gainers-13163085.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/stocks-to-watch-today-sai-life-sciences-kaynes-tech-gmm-pfaudler-axiscades-tech-natco-pharma-itd-cementation-oswal-pumps-in-focus-on-20-june-13150085.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/mid-smallcap-indices-jump-1-to-snap-3-day-losing-streak-waaree-energies-ireda-railtel-others-surge-up-to-6-13151369.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/hind-copper-hindalco-nalco-shares-rise-despite-overall-weakness-in-metals-heres-why-13138820.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/stocks-to-watch-today-zydus-lifesciences-tata-elxsi-abbott-india-esaf-small-finance-bank-siemens-energy-aegis-vopak-iks-health-in-focus-on-19-june-13143509.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/stocks-to-watch-today-titan-company-bharat-electronics-kpi-green-energy-m-m-brigade-enterprises-lemon-tree-hotels-in-focus-on-8-april-12987970.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/clsa-morgan-stanley-remain-cautious-on-it-says-discretionary-spending-still-weak-13143581.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/fiis-dump-rs-9-040-crore-worth-of-shares-diis-step-in-with-biggest-buying-since-feb-28-12987782.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/zydus-life-shares-in-focus-as-usfda-issues-2-observations-for-ahmedabad-facility-13143755.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/these-five-psus-are-eligible-to-exit-under-sebis-new-relaxed-delisting-norms-13146327.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/mtar-technologies-rebounds-3-after-securing-10-year-contract-with-weatherford-13145399.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/sensex-falls-700-pts-nifty-below-24-900-as-us-strikes-iran-all-sectors-in-red-india-vix-rises-4-13162105.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/sebi-approves-easier-norms-for-fpis-investing-only-in-government-bonds-13138254.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/hindustan-zinc-shares-plunge-3-extend-losses-for-seventh-session-should-you-buy-sell-or-hold-13144926.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/granules-india-shares-in-focus-after-usfda-issues-one-observation-to-hyderabad-units-13159916.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/nifty-realty-breaks-3-day-losing-streak-rises-over-3-led-by-brigade-prestige-godrej-properties-12988092.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/midcap-smallcap-indices-plunge-2-extend-losses-for-3rd-day-amid-broad-based-selling-here-are-the-top-losers-13145169.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/trade-spotlight-how-should-you-trade-eicher-motors-tata-consumer-products-m-m-wipro-bharti-airtel-and-others-on-june-20-13149202.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/cci-nod-impact-mahindra-mahindra-delhivery-shares-rise-up-to-2-13137791.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/ashish-kacholia-backed-aeroflex-industries-shares-rally-29-in-three-sessions-on-value-buying-13152155.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/stock-market-live-sensex-nifty-50-share-price-gift-nifty-latest-updates-08-04-2025-liveblog-12987997.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/stock-market-live-sensex-nifty-50-share-price-gift-nifty-latest-updates-23-06-2025stock-market-live-updates-gift-nifty-hints-a-weak-start-us-asian-markets-fall-amid-rising-middle-east-conflict-liveblog-13161906.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/wall-street-modestly-higher-as-oil-erases-gains-investor-weigh-fed-official-s-rate-cut-view-13165931.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/shares-acquired-in-fy25-but-credited-in-fy26-which-year-will-the-acquisition-be-counted-sebi-clears-the-air-13151657.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/dilip-buildcon-shares-surge-4-after-firm-wins-rs-1-341-crore-order-from-konkan-railway-13153321.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/futile-to-predict-future-stick-to-asset-allocation-dharma-says-kotaks-nilesh-shah-amid-market-turmoil-12987853.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/bloodbath-on-wall-street-s-p500-enters-bear-market-dow-jones-down-1-300-pts-amid-trade-war-fears-12987804.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/adani-ports-shares-drop-2-extend-losses-for-6th-session-amid-israel-iran-conflict-13138294.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/adani-ports-shares-fall-2-3-extend-decline-to-9-in-seven-sessions-amid-escalating-israel-iran-conflict-13145469.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/trade-spotlight-how-should-you-trade-kotak-mahindra-bank-bajaj-finance-gmr-airports-chambal-fertilizers-pnb-housing-and-others-on-april-8-12987972.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/sensex-nifty-set-for-weak-start-as-rising-us-israel-iran-tensions-jolt-sentiment-crude-oil-at-5-month-high-13161937.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/nifty-sensex-likely-to-see-muted-open-as-fed-fails-to-excite-markets-geopolitical-tensions-rise-13142429.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/sensex-down-650-pts-nifty-tests-24-950-amid-geopolitical-tensions-it-auto-lead-losses-broader-mkts-outshine-13162830.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/first-tick-here-are-the-top-global-cues-for-today-s-trade-118-13145380.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/one-mobikwik-systems-stock-tanks-8-as-shareholder-lock-in-period-ends-13137945.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/navin-fluorine-gets-third-buy-in-3-days-avendus-sets-rs-4-800-target-price-13137469.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/bse-indigo-shares-jump-up-to-3-on-likely-inclusion-into-nifty-50-13163620.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/taking-stock-nifty-ends-below-24-850-sensex-down-0-2-percent-eye-on-fomc-and-crude-13138175.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/siemens-shares-drop-2-5-after-bofa-maintains-underperform-call-siemens-energy-shares-down-1-13150729.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/shipping-corporation-stock-surges-4-amid-fears-of-disruption-in-strait-of-hormuz-13162712.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/next-market-cycle-to-be-a-barbell-rally-says-canara-robeco-amc-s-shridatta-bhandwaldar-13166198.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/trent-stock-jumps-2-emerges-as-one-of-top-nifty-gainers-on-bullish-brokerage-calls-here-s-what-analysts-say-13138174.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/sensex-up-650-pts-nifty-at-25-000-as-all-sectors-rally-india-vix-eases-nearly-6-13151434.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/zen-tech-stock-hits-5-upper-circuit-as-it-steps-into-uav-space-with-tisa-aerospace-buy-13163738.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/trent-shares-in-focus-as-hsbc-initiates-coverage-with-buy-rating-sees-17-upside-13150268.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/first-tick-here-are-the-top-global-cues-for-today-s-trade-80-12987227.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/nifty-psu-bank-snaps-3-day-losing-streak-rises-on-rbi-s-project-finance-push-13150652.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/gainers-losers-top-stocks-that-moved-the-most-on-june-18-13138479.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/delhivery-shares-drop-3-on-jefferies-downgrade-sees-another-8-potential-fall-13150536.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/nifty-it-sharply-down-on-selloff-after-fed-s-inflation-tariff-view-wipro-sole-gainer-on-upgrade-13144009.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/hero-motocorp-shares-rise-on-battery-subscription-push-for-new-vida-vx2-13144270.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/waaree-energies-shares-drop-2-on-us-senate-panel-s-plan-to-phase-out-solar-wind-incentives-13136889.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/dreamfolks-denies-partnership-cancellations-after-report-said-banks-and-card-network-sought-direct-pact-with-airport-lounges-13146004.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/united-spirits-shares-in-focus-as-it-fully-acquires-nao-spirits-in-rs-130-crore-deal-13150362.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/adani-enterprises-unit-commissions-india-s-first-off-grid-green-hydrogen-pilot-plant-shares-rise-1-5-13163444.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/bulk-block-deals-hdfc-mutual-fund-picks-0-56-equity-in-cyient-on-april-7-12987915.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/stock-market-live-sensex-nifty-50-share-price-gift-nifty-latest-updates-19-06-2025-liveblog-13143325.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/jefferies-shares-buy-call-for-sbi-sees-21-potential-upside-on-healthy-outlook-13150297.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/first-tick-here-are-the-top-global-cues-for-today-s-trade-119-13151928.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/should-investors-bet-on-banking-stocks-as-credit-growth-moderates-12988095.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/titan-shares-in-focus-as-revenue-rises-25-yoy-in-q4-business-update-12988015.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/sensex-nifty-set-for-a-flat-start-amid-middle-east-conflict-key-levels-to-track-on-june-20-13150131.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/sensex-nifty-trade-flat-as-it-psu-bank-metal-stocks-drag-small-midcaps-down-1-13144470.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/trent-shares-rise-for-second-day-up-3-as-brokerages-issue-bullish-calls-13163178.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/esaf-sfb-shares-surge-11-as-board-approves-to-offload-rs-735-cr-bad-loan-to-arc-13143925.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/trade-spotlight-how-should-you-trade-indus-towers-kotak-mahindra-bank-nrb-bearings-icici-lombard-kfin-technologies-m-m-and-others-on-june-23-13161465.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/trade-spotlight-how-should-you-trade-asahi-india-glass-avenue-supermarts-au-small-finance-bank-cyient-vedant-fashions-and-others-on-june-19-13142386.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/sensex-down-200-pts-nifty-below-24-800-as-it-oil-gas-metal-stocks-fall-13137458.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/polycab-shares-rise-5-on-jefferies-bullish-note-that-sees-19-upside-potential-13164819.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/taking-stock-bulls-back-in-action-sensex-up-1-046-pts-nifty-above-25-100-13152631.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/listed-for-years-still-these-psus-have-not-complied-with-public-shareholding-norm-here-s-why-13145143.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/stock-market-live-sensex-nifty-50-share-price-gift-nifty-latest-updates-20-06-2025-liveblog-13150034.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/sensex-nifty-set-to-extend-losses-for-a-second-straight-session-it-metal-stocks-witness-selloff-13138360.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/kaynes-tech-shares-jump-2-after-firm-launches-qip-to-raise-up-to-rs-1-600-crore-13150654.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/hpcl-bpcl-ioc-slip-as-brent-inches-towards-77-amid-escalating-iran-israel-war-ongc-shares-rise-13146067.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/metal-realty-stocks-tumble-up-to-3-as-us-fed-s-hawkish-stance-weighs-in-13144274.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/sebi-calls-for-responsible-ethical-use-of-ai-in-securities-market-floats-consultation-paper-13154132.html
# ✅ Completed: https://www.moneycontrol.com/news/business/markets/taking-stock-sensex-nifty-end-lower-in-rangebound-session-broader-indices-worst-hit-13145506.html

# %%
def parse_article_timestamp(timestamp: str) -> datetime | None:
    """
    Parse a Moneycontrol-style timestamp into a datetime object.

    Args:
        timestamp (str): The raw timestamp string from the article.

    Returns:
        datetime | None: A datetime object if parsing is successful, else None.
    """
    try:
        if not timestamp:
            return None

        # Normalize string
        timestamp = timestamp.strip()
        # Remove trailing time zone and slashes, e.g., "/ 09:30 IST"
        timestamp = re.sub(r"/\s*\d{2}:\d{2}\s*IST", "", timestamp)

        # Extract date and (optional) time
        match = re.search(r'([A-Za-z]+\s+\d{1,2},\s+\d{4})/?\s*(\d{2}:\d{2})?', timestamp)
        if not match:
            return None

        date_part = match.group(1)
        time_part = match.group(2) or "00:00"

        full_string = f"{date_part} {time_part}"
        return datetime.strptime(full_string, "%B %d, %Y %H:%M")
    
    except Exception as e:
        print(f"❌ Error parsing timestamp: {timestamp} | {e}")
        return None

def filter_recent_articles(articles: list[dict], hours: int = 24) -> list[dict]:
    """
    Filter articles published in the last `hours` hours.

    Args:
        articles (list): List of article dicts (each containing a 'timestamp' key).
        hours (int): Time range to filter in hours (default 24).

    Returns:
        list: Articles published within the given time window.
    """
    cutoff = datetime.now() - timedelta(hours=hours)
    recent = []

    for article in articles:
        dt = parse_article_timestamp(article.get("timestamp", ""))
        if dt and dt >= cutoff:
            recent.append(article)

    return recent


recent_articles_raw = filter_recent_articles(all_articles_raw, hours=24)

# %%
def format_articles_to_string(articles: list[dict]) -> str:
    """
    Takes a list of article dicts and returns a formatted string with
    title, timestamp, and content for each article.

    Args:
        articles (list): List of article dictionaries.

    Returns:
        str: Formatted string combining the articles.
    """
    result = []
    for article in articles:
        title = article.get("title", "No Title")
        timestamp = article.get("timestamp", "No Timestamp")
        content = article.get("content", "No Content")

        # Skip articles with no content
        if not content or not isinstance(content, str) or content.strip() == "":
            continue

        formatted = f"📰 {title}\n🕒 {timestamp}\n\n{content.strip()}\n{'-' * 80}"
        result.append(formatted)

    return "\n\n".join(result)

# %%
recent_articles_text = format_articles_to_string(recent_articles_raw)

# %%
import os
import textwrap
from google import genai

def create_morning_report(recent_articles_text):
	client = genai.Client(api_key=os.getenv('GEMINI_API_KEY'))

	prompt = f"""
		You are a financial analyst generating a comprehensive Premarket Report for equity traders in India.

		Based on the following raw market news and updates, write a concise, actionable, and well-structured report suitable to be read by traders before the Indian stock market opens.

		The report should include:
		- 🔔 A crisp summary of global cues (GIFT Nifty, US markets, crude, gold, dollar index, bond yields, Asian markets)
		- 📊 Domestic market setup: Nifty/Sensex close, support/resistance levels, VIX, FII/DII flows, PCR
		- 🔍 Stocks in Focus with reason (news impact, earnings, regulatory update, deals, etc.)
		- 💹 Top Trading Ideas (stock, CMP, buy/sell, target, SL)
		- 📢 Corporate actions or events (dividends, bonus, board meetings, SME listings)
		- 🧾 Bulk/Block deals or fund flow highlights
		- ⚠️ Risks to watch (macro, geopolitical, etc.)
		- ✅ A strategy summary to guide the trading day

		Remove any fluff before the first emoji section like 🔔 or 📊.
		Format the output using emojis and headers to make it engaging and scannable. Keep the tone clear, professional, and trader-friendly.

		Here is the raw input: {recent_articles_text} """

	# Generate text
	response = client.models.generate_content(
		model="gemini-2.5-flash",
		contents=prompt
	)

	return response.text

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import markdown

def send_email_report(report_text, subject="📈 Premarket Report", to_email="mdnishan006@gmail.com"):
    # Configuration
    from_email = "mdnishan006@gmail.com"
    app_password = "mciu itco kbmp mnvd"  # Use your 16-character app password

    # Convert markdown to HTML
    report_html = markdown.markdown(report_text)

    # Construct the email
    msg = MIMEMultipart("alternative")
    msg['From'] = from_email
    msg['To'] = to_email
    msg['Subject'] = subject

    # Attach both plain and HTML versions
    # msg.attach(MIMEText(report_text, "plain"))
    msg.attach(MIMEText(report_html, "html"))

    # Send the email via Gmail SMTP
    try:
        with smtplib.SMTP_SSL("smtp.gmail.com", 465) as server:
            server.login(from_email, app_password)
            server.send_message(msg)
        print("✅ Email sent successfully.")
    except Exception as e:
        print(f"❌ Failed to send email: {e}")

# %%
morning_report = create_morning_report(recent_articles_text)
send_email_report(morning_report, subject="📈 Daily Premarket Report", to_email="mdnishan006@gmail.com")
